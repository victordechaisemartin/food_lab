# %% [markdown]
# # FOODLAB PROJECT

# %% [markdown]
# ## Importing our Data

# %%
import pandas as pd

# %%
recipes = pd.read_csv("./archive/RAW_recipes.csv")
recipes.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# ...

# %%
cereals = pd.read_excel("BioFoodComp4.0.xlsx", sheet_name="01 Cereals")
cereals.head()
# Out:
#    Food Item ID                            Code    Country, region  \
# 0           NaN  as used in version 1.0 and 1.1     sampling place
# 1      100001.0                          010017  Benin, North West
# 2      100002.0                          010018  Benin, North West
# 3      100003.0                          010023              Benin
# 4      100004.0                          010024              Benin
#
#                                                 Type  \
# 0  C: Cultivar, V: Variety, BC: Breeding Clone, B...
# 1                                                  C
# 2                                                  C
# 3                                                  C
# 4                                                  C
#
#    Foodname in own language               Foodname in English  \
# 0                       NaN                               NaN
# 1                       NaN  Sorghum, whole grain, white, raw
# ...

# %%
cereals['Foodname in English'].unique()
# Out:
# array([nan, 'Sorghum, whole grain, white, raw',
#        'Sorghum, whole grain, red, raw', 'Maize, Gnonli, dried, raw ',
#        'Maize, Gougba, dried, raw', 'Maize, Gbaévè, dried, raw',
#        'Maize, DMR-ESR-W, dried, raw',
#        'Maize, POZA - RICA 7843 - SR, dried, raw',
#        'Maize, TZPB-SR, dried, raw',
#        'Quinoa, Oca suca, abrasive dehulling, raw',
#        'Quinoa, Blanca de Juli, abrasive dehulling, raw',
#        'Quinoa, Blanca de Junin, abrasive dehulling, raw',
#        'Quinoa, Puno 8-80, abrasive dehulling, raw',
#        'Quinoa, Puno -15, abrasive dehulling, raw',
#        'Quinoa, Kancolla, abrasive dehulling, raw',
#        'Quinoa, Cheweca, abrasive dehulling, raw',
#        'Quinoa, Kancolla Rosanna, abrasive dehulling, raw',
#        'Quinoa, Real, abrasive dehulling, raw',
#        'Quinoa, Kaslala, abrasive dehulling, raw',
#        'Quinoa, Wila Coymini, abrasive dehulling, raw',
#        'Quinoa, Janku, abrasive dehulling, raw',
# ...
